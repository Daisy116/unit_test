# %%
from selenium import webdriver
from bs4 import BeautifulSoup

browser = webdriver.Chrome('./chromedriver')
browser.get('http://live2.gooooal.com/')

i = 0
soup = BeautifulSoup(browser.page_source)
# print(soup.select('.match-table tbody td'))
for ele in soup.select('.match-table tbody td'):
    if i > 1 :
        print(i, ele.text)
    i = i + 1
    
browser.close()
# Out:
# 2 欧U19预
# 3 18:00
# 4 未
# 5 小组赛-B
# 6 西班牙(U19)
# 7 vs
# 8 立陶宛(U19)
# 9 -
# 10 1.81-3.5/42.01
# 11 1.81
# 12 -3.5/4
# 13 2.01
# 14
# 15
# 16
# 17
# 18 欧女U19预
# 19 18:00
# 20 未
# 21 小组赛
# 22 [B2]捷克女足(U19)
# 23 vs
# 24 芬兰女足(U19)[B1]
# 25 -
# 26
# 27
# 28 欧女U19预第一阶段小组赛
# 29
# 30
# 31
# 32 欧女U19预
# 33 18:00
# 34 未
# 35 小组赛
# 36 [B3]立陶宛女足(U19)
# 37 vs
# 38 法罗群岛女足(U19)[B4]
# 39 -
# 40
# 41
# 42
# 43
# 44
# 45 欧女U19预
# 46 18:00
# 47 未
# 48 小组赛
# 49 [C1]葡萄牙女足(U19)
# 50 vs
# 51 德国女足(U19)[C2]
# 52 -
# 53
# 54
# 55
# 56
# 57
# 58
# 59 欧女U19预
# 60 18:00
# 61 未
# 62 小组赛
# 63 [C4]阿尔巴尼亚女足(U19)
# 64 vs
# 65 阿塞拜疆女足(U19)[C3]
# 66 -
# 67
# 68
# 69
# 70
# 71
# 72 欧女U17预
# 73 18:30
# 74 未
# 75 小组赛
# 76 [I1]匈牙利女足(U17)
# 77 vs
# 78 波兰女足(U17)[I2]
# 79 -
# 80
# 81
# 82 欧女U17预第一阶段小组赛
# 83
# 84
# 85
# 86 欧女U17预
# 87 18:30
# 88 未
# 89 小组赛
# 90 [I4]哈萨克斯坦女足(U17)
# 91 vs
# 92 保加利亚女足(U17)[I3]
# 93 -
# 94
# 95
# 96
# 97
# 98
# 99 欧U19预
# 100 19:00
# 101 未
# 102 小组赛-L
# 103 荷兰(U19)
# 104 vs
# 105 摩尔多瓦(U19)
# 106 -
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from openpyxl import Workbook

# 創建一個空白活頁簿物件
wb = Workbook()
# 選取正在工作中的表單
ws = wb.active

# browser = webdriver.Chrome()
browser = webdriver.Chrome('./chromedriver')
browser.get('http://live2.gooooal.com/')
soup = BeautifulSoup(browser.page_source)

i = 0
for ele in soup.select('.match-table tbody td'):
    #主隊 .home-team-td .team
    if i > 1 :
        print(i, ele.text)
        ws.cell(row=1, column = 2, value = ele.text)
    i = i + 1

browser.close()
# 儲存成 create_sample.xlsx 檔案
wb.save('live2.xlsx')

# %%
import requests
from bs4 import BeautifulSoup

# 使用 GET 方式下載普通網頁
r = requests.get('http://live2.gooooal.com/')
# 轉成網頁 HTML 原始碼
html_str = r.text
soup = BeautifulSoup(html_str)
# res = requests.get('https://www.qiushibaike.com/hot/#')  #以糗事百科为例
# soup = BeautifulSoup(r,'html.parser')

# print(soup)
rating_selector = "match-table tbody td"
print(soup.select(rating_selector))

for ele in soup.select('.match-table tbody td'):
    print(ele.text)


# rating_selector = "strong span"
# rating = [float(i.text) for i in soup.select(rating_selector)][0]

# print(type(soup))
# print(soup.select(rating_selector))
# print(rating)
# print('over')

# %%
import requests
from bs4 import BeautifulSoup

# getting data
r = requests.get("https://www.imdb.com/title/tt4154796")
html_str = r.text
# parsing data
soup = BeautifulSoup(html_str)
rating_selector = "strong span"
rating = [float(i.text) for i in soup.select(rating_selector)][0]
print(type(soup))
print(soup.select(rating_selector))
print(rating)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# browser = webdriver.Chrome()
browser = webdriver.Chrome('./chromedriver')
browser.get('http://app.gooooal.com/footBallDataBaseAction.do?method=doFootBallDataBase')
soup = BeautifulSoup(browser.page_source)

print(soup)
# for ele in soup.select('.panel_list_cont div div div span'):
#     print(ele.text)
# for ele in soup.select('.panel_list_cont div div table tbody tr td center span a'):
#     print(ele.text)

# for ele in soup.select('.left div div span'):
#     print(ele.text)
    
# for ele in soup.select('.left div table tbody tr td center span a'):
#     print(ele.text)
    
browser.close()

print('over')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# browser = webdriver.Chrome()
browser = webdriver.Chrome('./chromedriver')
browser.get('http://app.gooooal.com/footBallDataBaseAction.do?method=doFootBallDataBase')
soup = BeautifulSoup(browser.page_source)

# for ele in soup.select('.panel_list_cont div div div span'):
#     print(ele.text)
# for ele in soup.select('.panel_list_cont div div table tbody tr td center span a'):
#     print(ele.text)
    
for ele in soup.select('.right div div span'):
    print(ele.text)
    
for ele in soup.select('.right div table tbody tr td center span a'):
    print(ele.text)
    
browser.close()

print('over')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
weblist = []

weblist.append('http://app.gooooal.com/competition.do?lid=1&sid=2019&pid=19&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=2&sid=2019&pid=14&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=3&sid=2019&pid=1&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=4&sid=2019&pid=6&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=5&sid=2019&pid=23&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=6&sid=2019&pid=28&lang=tr')

weblist.append('http://app.gooooal.com/competition.do?lid=12&sid=2019&pid=44&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=30&sid=2019&pid=31&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=33&sid=2019&pid=41&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=34&sid=2019&pid=54&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=35&sid=2019&pid=58&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=37&sid=2019&pid=62&lang=tr')

weblist.append('http://app.gooooal.com/competition.do?lid=50&sid=2019&pid=66&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=51&sid=2019&pid=50&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=52&sid=2019&pid=69&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=53&sid=2019&pid=84&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=54&sid=2019&pid=75&lang=tr')
weblist.append('http://app.gooooal.com/competition.do?lid=55&sid=2019&pid=72&lang=tr')

for each_web in weblist:
    print(each_web)
    browser = webdriver.Chrome('./chromedriver')
    browser.get(each_web)
    soup = BeautifulSoup(browser.page_source)

    print('聯賽名稱')
    for ele in soup.select('.txt_24.left'):
        print(ele.text)

    print('\n球隊名稱')
    for ele in soup.select('.integrTab tbody tr td a'):
        print(ele.text)
    
    browser.close()
    
print('over')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# browser = webdriver.Chrome()
browser = webdriver.Chrome('./chromedriver')
browser.get('http://app.gooooal.com/footBallDataBaseAction.do?method=doFootBallDataBase')
soup = BeautifulSoup(browser.page_source)

print('欧洲联赛')
for ele in soup.select('.left div table tbody tr td center span a'):
    print(ele['href'])
    
browser.close()

print('over')

# %%
print('123\n')
print('456')

# %%
# https://blog.techbridge.cc/2018/10/05/how-to-use-python-manipulate-excel-spreadsheet/
from openpyxl import load_workbook

wb = load_workbook('Financial Sample.xlsx')

ws = wb.active
ws['A1'].value

# 列出每一欄的值
# for row in ws.rows:
#     for cell in row:
#         print(cell.value)
        
# 列出每一列的值
for column in ws.columns:
    for cell in column:
        print(cell.value)

# %%
from openpyxl import Workbook

# 創建一個空白活頁簿物件
wb = Workbook()

# 選取正在工作中的表單
ws = wb.active

# 指定值給 A1 儲存格
ws['A1'] = '我是儲存格'

# 向下新增一列並連續插入值
ws.append(['是是是', '否否否', '宜宜宜'])
ws.append([3, 2, 1])

ws.cell(row=4, column=2, value=10)

# 儲存成 create_sample.xlsx 檔案
wb.save('create2.xlsx')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from openpyxl import Workbook

# 創建一個空白活頁簿物件
wb = Workbook()
# 選取正在工作中的表單
ws = wb.active

# browser = webdriver.Chrome()
browser = webdriver.Chrome('./chromedriver')
browser.get('http://app.gooooal.com/footBallDataBaseAction.do?method=doFootBallDataBase')
soup = BeautifulSoup(browser.page_source)

for ele in soup.select('.right div div span'):
    print(ele.text)
#     ws.append([ele.text])
    ws.cell(row=1, column = 2, value = ele.text)

i = 2
for ele in soup.select('.right div table tbody tr td center span a'):
    print(ele.text)
#     ws.append([ele.text])
    ws.cell(row = i, column = 2, value = ele.text)
    i = i + 1
    
browser.close()

browser = webdriver.Chrome('./chromedriver')
browser.get('http://app.gooooal.com/footBallDataBaseAction.do?method=doFootBallDataBase')
soup = BeautifulSoup(browser.page_source)

for ele in soup.select('.left div div span'):
    print(ele.text)
    ws.cell(row=1, column = 1, value = ele.text)

j = 2
for ele in soup.select('.left div table tbody tr td center span a'):
    print(ele.text)
    ws.cell(row=j, column = 1, value = ele.text)
    j = j + 1
    
browser.close()

# 儲存成 create_sample.xlsx 檔案
wb.save('create.xlsx')

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from openpyxl import Workbook

# 創建一個空白活頁簿物件
wb = Workbook()
# 選取正在工作中的表單
ws = wb.active

# browser = webdriver.Chrome()
browser = webdriver.Chrome('./chromedriver')
browser.get('http://live2.gooooal.com/')
soup = BeautifulSoup(browser.page_source)

i = 0
for ele in soup.select('.match-table tbody td'):
    if i > 1 :
        print(i, ele.text)
        ws.cell(row=1, column = 2, value = ele.text)
    i = i + 1

browser.close()
# 儲存成 create_sample.xlsx 檔案
wb.save('live2.xlsx')

# %%
from selenium import webdriver 
broswer = webdriver.Chrome() 

#訪問淘寶頁面 
broswer.get('https://www.taobao.com') 

#獲取頁面原始碼 
print(broswer.page_source) 

#關閉 
broswer.close()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
 
browser = webdriver.Chrome()
try:
    browser.get('https://www.baidu.com')
    input = browser.find_element_by_id('kw')
    input.send_keys('Python')
    input.send_keys(Keys.ENTER)
    wait = WebDriverWait(browser, 10)
    wait.until(EC.presence_of_element_located((By.ID, 'content_left')))
    
    # 輸出當前的URL
    print(browser.current_url)
    
    # 輸出當前的Cookies
    print(browser.get_cookies())
    
    # 網頁源代碼
    print(browser.page_source)
finally:
    browser.close()

# %%
import requests as rq
from bs4 import BeautifulSoup

url = "https://www.ptt.cc/bbs/NBA/index.html" # PTT NBA 板
response = rq.get(url) # 用 requests 的 get 方法把網頁抓下來
html_doc = response.text # text 屬性就是 html 檔案
soup = BeautifulSoup(response.text, "lxml") # 指定 lxml 作為解析器
print(soup.prettify()) # 把排版後的 html 印出來
